# %% [markdown]
# # X-ray 이미지로 폐렴 진단하기

# %% [markdown]
# - DNN을 활용해 폐렴 이미지를 구분한다.

# %% [markdown]
# ![image](https://user-images.githubusercontent.com/86637320/130712505-89911511-1c10-4726-b7a0-bdd710530ab4.png)

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*'
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25
# Out:
# /aiffel/aiffel

# %% [markdown]
# ## 1. 데이터 준비하기

# %% [markdown]
# val 데이터가 너무 적다!

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# train과 val을 합친 다음에 랜덤으로 80:20 비율로 할당해준다.

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %% [markdown]
# **normal/pneumonia**는 폴더로 구분

# %%
# 정상 이미지와 폐렴 이미지를 구분해야 하는데
# 다행히도 파일 경로에 힌트가 있어요
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-0627-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person569_bacteria_2360.jpeg

# %% [markdown]
# imbalanced 데이터 : pneumonia가 훨씬 많다.

# %%
# 이제 파일 경로에 NORMAL이 있는지 확인하면 정상 이미지를 셀 수 있습니다.
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")

# 파일 경로에 PNEUMONIA이 있는지 확인하면 폐렴 이미지도 셀 수 있습니다.
COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %% [markdown]
# **tf.data** - 학습 때 배치처리 작업을 보다 효율적으로 할 수 있다.

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy() #개수 세기
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# **Labeling**

# %% [markdown]
# file_path를 os.path.sep을 기준으로 split

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %% [markdown]
# 이미지 크기 조절, 라벨링

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %% [markdown]
# ### Train/Val

# %% [markdown]
# AUTOTUNE 사용으로 빠르게 처리

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %% [markdown]
# ### Test

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat() #epoch 횟수만큼 repeat
    ds = ds.batch(BATCH_SIZE) 
    ds = ds.prefetch(buffer_size=AUTOTUNE) #학습 데이터 나눠서 읽어와 GPU에서 학습하는 동안 다음 데이터를 CPU에서 준비
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# show batch images

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## 2. 모델 구성

# %% [markdown]
# Conv - Conv - BN - MaxPool

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %% [markdown]
# BN과 Dropout이 동시에 사용 => 도움이 될까?

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# **불균형**데이터 처리 : 가중치를 다르게 업데이트하자

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 180, 180, 16)      448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 180, 180, 16)      2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# sequential (Sequential)      (None, 45, 45, 32)        2160
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 22, 22, 64)        7392
# _________________________________________________________________
# sequential_2 (Sequential)    (None, 11, 11, 128)       27072
# _________________________________________________________________
# dropout (Dropout)            (None, 11, 11, 128)       0
# _________________________________________________________________
# sequential_3 (Sequential)    (None, 5, 5, 256)         103296
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 5, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 512)               3279360
# _________________________________________________________________
# sequential_5 (Sequential)    (None, 128)               66176
# _________________________________________________________________
# sequential_6 (Sequential)    (None, 64)                8512
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 3,496,801
# Trainable params: 3,494,433
# Non-trainable params: 2,368
# _________________________________________________________________

# %% [markdown]
# ## 3. 모델 훈련하기

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 54s 138ms/step - loss: 0.6281 - accuracy: 0.6672 - precision: 0.8971 - recall: 0.6325 - val_loss: 0.5835 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.2645 - accuracy: 0.8704 - precision: 0.9706 - recall: 0.8531 - val_loss: 0.9102 - val_accuracy: 0.7337 - val_precision: 0.7337 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1886 - accuracy: 0.9176 - precision: 0.9797 - recall: 0.9086 - val_loss: 0.1171 - val_accuracy: 0.9558 - val_precision: 0.9852 - val_recall: 0.9542
# Epoch 4/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1919 - accuracy: 0.9288 - precision: 0.9780 - recall: 0.9261 - val_loss: 0.0968 - val_accuracy: 0.9635 - val_precision: 0.9802 - val_recall: 0.9700
# Epoch 5/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1342 - accuracy: 0.9530 - precision: 0.9863 - recall: 0.9495 - val_loss: 0.3037 - val_accuracy: 0.8673 - val_precision: 1.0000 - val_recall: 0.8196
# Epoch 6/25
# 261/261 [==============================] - 34s 132ms/step - loss: 0.1336 - accuracy: 0.9462 - precision: 0.9871 - recall: 0.9398 - val_loss: 0.1559 - val_accuracy: 0.9481 - val_precision: 0.9917 - val_recall: 0.9373
# Epoch 7/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1451 - accuracy: 0.9452 - precision: 0.9864 - recall: 0.9401 - val_loss: 0.0967 - val_accuracy: 0.9663 - val_precision: 0.9656 - val_recall: 0.9896
# Epoch 8/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1653 - accuracy: 0.9333 - precision: 0.9813 - recall: 0.9272 - val_loss: 0.1878 - val_accuracy: 0.9202 - val_precision: 0.9025 - val_recall: 1.0000
# Epoch 9/25
# 261/261 [==============================] - 34s 132ms/step - loss: 0.1493 - accuracy: 0.9483 - precision: 0.9826 - recall: 0.9468 - val_loss: 0.5367 - val_accuracy: 0.8000 - val_precision: 0.9982 - val_recall: 0.7294
# Epoch 10/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1474 - accuracy: 0.9450 - precision: 0.9862 - recall: 0.9403 - val_loss: 0.1266 - val_accuracy: 0.9558 - val_precision: 0.9444 - val_recall: 0.9987
# Epoch 11/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1348 - accuracy: 0.9504 - precision: 0.9861 - recall: 0.9469 - val_loss: 0.0802 - val_accuracy: 0.9702 - val_precision: 0.9946 - val_recall: 0.9647
# Epoch 12/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1566 - accuracy: 0.9408 - precision: 0.9806 - recall: 0.9396 - val_loss: 0.3561 - val_accuracy: 0.8702 - val_precision: 1.0000 - val_recall: 0.8235
# Epoch 13/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1097 - accuracy: 0.9524 - precision: 0.9899 - recall: 0.9471 - val_loss: 0.0499 - val_accuracy: 0.9798 - val_precision: 0.9895 - val_recall: 0.9830
# Epoch 14/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.0960 - accuracy: 0.9656 - precision: 0.9890 - recall: 0.9645 - val_loss: 0.0939 - val_accuracy: 0.9673 - val_precision: 1.0000 - val_recall: 0.9556
# Epoch 15/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0875 - accuracy: 0.9701 - precision: 0.9914 - recall: 0.9679 - val_loss: 0.0575 - val_accuracy: 0.9779 - val_precision: 0.9781 - val_recall: 0.9921
# Epoch 16/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1020 - accuracy: 0.9610 - precision: 0.9914 - recall: 0.9562 - val_loss: 0.0543 - val_accuracy: 0.9808 - val_precision: 0.9921 - val_recall: 0.9817
# Epoch 17/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1163 - accuracy: 0.9578 - precision: 0.9883 - recall: 0.9550 - val_loss: 0.0819 - val_accuracy: 0.9750 - val_precision: 0.9719 - val_recall: 0.9948
# Epoch 18/25
# 261/261 [==============================] - 34s 132ms/step - loss: 0.0886 - accuracy: 0.9645 - precision: 0.9924 - recall: 0.9599 - val_loss: 0.0855 - val_accuracy: 0.9673 - val_precision: 0.9919 - val_recall: 0.9634
# Epoch 19/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0918 - accuracy: 0.9638 - precision: 0.9927 - recall: 0.9591 - val_loss: 0.0529 - val_accuracy: 0.9827 - val_precision: 0.9908 - val_recall: 0.9856
# Epoch 20/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0560 - accuracy: 0.9810 - precision: 0.9939 - recall: 0.9801 - val_loss: 0.1305 - val_accuracy: 0.9558 - val_precision: 1.0000 - val_recall: 0.9399
# Epoch 21/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0784 - accuracy: 0.9727 - precision: 0.9931 - recall: 0.9698 - val_loss: 0.0804 - val_accuracy: 0.9702 - val_precision: 0.9946 - val_recall: 0.9648
# Epoch 22/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0816 - accuracy: 0.9722 - precision: 0.9927 - recall: 0.9700 - val_loss: 0.0671 - val_accuracy: 0.9731 - val_precision: 0.9933 - val_recall: 0.9699
# Epoch 23/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.0793 - accuracy: 0.9695 - precision: 0.9906 - recall: 0.9678 - val_loss: 0.0539 - val_accuracy: 0.9837 - val_precision: 0.9882 - val_recall: 0.9895
# Epoch 24/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.0559 - accuracy: 0.9813 - precision: 0.9964 - recall: 0.9782 - val_loss: 0.1585 - val_accuracy: 0.9375 - val_precision: 0.9930 - val_recall: 0.9216
# Epoch 25/25
# 261/261 [==============================] - 34s 132ms/step - loss: 0.0956 - accuracy: 0.9679 - precision: 0.9926 - recall: 0.9644 - val_loss: 0.0578 - val_accuracy: 0.9827 - val_precision: 0.9882 - val_recall: 0.9882

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# 모델 평가

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 3s 73ms/step - loss: 0.9963 - accuracy: 0.7901 - precision: 0.7486 - recall: 1.0000
# Loss: 0.99632328748703,
# Accuracy: 0.7900640964508057,
# Precision: 0.7485604882240295,
# Recall: 1.0

# %% [markdown]
# ___

# %% [markdown]
# # 성능 개선

# %% [markdown]
# 의료 데이터는 구하기 힘들기 때문에 data augmentation 진행

# %% [markdown]
# Data Aumentation
# - 이동, 회전, 가우시안 노이즈 추가한 이미지

# %% [markdown]
# 이때 폐렴 이미지의 경우 가우시안 노이즈 적용 시 주의 필요

# %% [markdown]
# 좌우/상하 반전 이미지만 추가로 사용하자

# %% [markdown]
# Dropout + BN ?

# %% [markdown]
# - 특이한 구조인데 정말 도움이 될까?

# %% [markdown]
# Val loss가 변동이 심한데 regularization 추가?

# %% [markdown]
# ## 4. 성능 개선

# %%
def augment1(image,label):
    
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label
    
def augment2(image,label):
    
    image = tf.image.random_flip_up_down(image)  # 랜덤하게 상하를 반전합니다.
    return image,label
    
def prepare_for_training(ds, shuffle_buffer_size=1000):
        
    ds = ds.map(augment1,num_parallel_calls=2)
    ds = ds.map(augment2,num_parallel_calls=2)
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat() #epoch 횟수만큼 repeat
    ds = ds.batch(BATCH_SIZE) 
    ds = ds.prefetch(buffer_size=AUTOTUNE) #학습 데이터 나눠서 읽어와 GPU에서 학습하는 동안 다음 데이터를 CPU에서 준비
    return ds

# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
    
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
    
train_ds = prepare_for_training(train_ds)

image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %%
def modify_params(BATCH_SIZE = 16,epoches = 25,optimizer = 'adam',rugularizer = 0,class_weight = class_weight,augment = True):
    
    # 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
    def get_label(file_path):
        parts = tf.strings.split(file_path, os.path.sep)
        return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

    # 이미지를 알맞은 형식으로 바꿉니다.
    def decode_img(img):
        img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
        img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
        img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
        return img

    # 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
    def process_path(file_path):
        label = get_label(file_path) # 라벨 검출
        img = tf.io.read_file(file_path) # 이미지 읽기
        img = decode_img(img) # 이미지를 알맞은 형식으로 수정
        return img, label
    
    def augment1(image,label):
        image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
        return image,label
    
    def augment2(image,label):
        image = tf.image.random_flip_up_down(image)  # 랜덤하게 상하를 반전합니다.
        return image,label
    
    def prepare_for_training(ds, shuffle_buffer_size=1000):
        
        ds = ds.map(augment1,num_parallel_calls=2)
        ds = ds.map(augment2,num_parallel_calls=2)
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
        ds = ds.repeat() #epoch 횟수만큼 repeat
        ds = ds.batch(BATCH_SIZE) 
        ds = ds.prefetch(buffer_size=AUTOTUNE) #학습 데이터 나눠서 읽어와 GPU에서 학습하는 동안 다음 데이터를 CPU에서 준비
        return ds
    
    train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
    val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)
    
    train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
    val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
    
    train_ds = prepare_for_training(train_ds)
    val_ds = prepare_for_training(val_ds)
    
    test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
    TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
    test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
    test_ds = test_ds.batch(BATCH_SIZE)
    
    
    #model
    def conv_block(filters):
        block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
        return block
    
    def dense_block(units, dropout_rate):
        block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        #tf.keras.layers.Dropout(dropout_rate)
    ])
    
        return block
    
    def build_model():
        model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
        return model
    
    with tf.device('/GPU:0'):
        model = build_model()
        
        earlystopping = EarlyStopping(monitor='val_loss',  # 모니터 기준 설정 (val loss) 
                              patience=4,         # 4회 Epoch동안 개선되지 않는다면 종료
                             )

        METRICS = [
            'accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
                    ]
    
        model.compile(
            optimizer= optimizer,
            loss='binary_crossentropy',
            metrics=METRICS
                    )
    
        history = model.fit(
            train_ds,
            steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
            epochs=EPOCHS,
            validation_data=val_ds,
            validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
            class_weight=class_weight,
            callbacks = earlystopping
                            )
    
    loss, accuracy, precision, recall = model.evaluate(test_ds)
    print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
    
    eval_result = {'loss' : loss, 'accuracy' : accuracy, 'precision' : precision, 'recall' : recall}
    
    return history, eval_result

# %%
def plot(history):

    fig, ax = plt.subplots(1, 4, figsize=(20, 3))
    ax = ax.ravel()

    for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
        ax[i].plot(history.history[met])
        ax[i].plot(history.history['val_' + met])
        ax[i].set_title('Model {}'.format(met))
        ax[i].set_xlabel('epochs')
        ax[i].set_ylabel(met)
        ax[i].legend(['train', 'val'])

# %% [markdown]
# #### 모델1 : BATCH_SIZE = 16,epoches = 25,optimizer = 'adam',rugularizer = 0,class_weight = class_weight,augment = True

# %%
model1 = modify_params()
# Out:
# Epoch 1/25
# 261/261 [==============================] - 42s 133ms/step - loss: 0.5973 - accuracy: 0.6810 - precision: 0.8906 - recall: 0.6537 - val_loss: 0.6506 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.2780 - accuracy: 0.8885 - precision: 0.9693 - recall: 0.8777 - val_loss: 1.1376 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.2873 - accuracy: 0.8890 - precision: 0.9658 - recall: 0.8835 - val_loss: 0.1368 - val_accuracy: 0.9510 - val_precision: 0.9851 - val_recall: 0.9477
# Epoch 4/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.2110 - accuracy: 0.9146 - precision: 0.9749 - recall: 0.9084 - val_loss: 0.1335 - val_accuracy: 0.9510 - val_precision: 0.9811 - val_recall: 0.9516
# Epoch 5/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.1989 - accuracy: 0.9187 - precision: 0.9828 - recall: 0.9077 - val_loss: 0.4349 - val_accuracy: 0.8067 - val_precision: 0.9982 - val_recall: 0.7392
# Epoch 6/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.2074 - accuracy: 0.9110 - precision: 0.9763 - recall: 0.9031 - val_loss: 0.2038 - val_accuracy: 0.9038 - val_precision: 0.9911 - val_recall: 0.8771
# Epoch 7/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.1681 - accuracy: 0.9278 - precision: 0.9814 - recall: 0.9203 - val_loss: 0.1444 - val_accuracy: 0.9481 - val_precision: 0.9904 - val_recall: 0.9387
# Epoch 8/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.2038 - accuracy: 0.9308 - precision: 0.9743 - recall: 0.9317 - val_loss: 0.0943 - val_accuracy: 0.9673 - val_precision: 0.9679 - val_recall: 0.9882
# Epoch 9/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.1653 - accuracy: 0.9284 - precision: 0.9794 - recall: 0.9221 - val_loss: 0.3966 - val_accuracy: 0.8298 - val_precision: 0.9949 - val_recall: 0.7723
# Epoch 10/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1775 - accuracy: 0.9348 - precision: 0.9801 - recall: 0.9309 - val_loss: 0.1539 - val_accuracy: 0.9308 - val_precision: 0.9943 - val_recall: 0.9110
# Epoch 11/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1569 - accuracy: 0.9350 - precision: 0.9857 - recall: 0.9274 - val_loss: 0.6044 - val_accuracy: 0.7183 - val_precision: 1.0000 - val_recall: 0.6170
# Epoch 12/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1748 - accuracy: 0.9267 - precision: 0.9841 - recall: 0.9172 - val_loss: 0.0842 - val_accuracy: 0.9750 - val_precision: 0.9731 - val_recall: 0.9935
# Epoch 13/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1400 - accuracy: 0.9461 - precision: 0.9863 - recall: 0.9414 - val_loss: 0.1466 - val_accuracy: 0.9356 - val_precision: 0.9902 - val_recall: 0.9217
# Epoch 14/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1686 - accuracy: 0.9365 - precision: 0.9830 - recall: 0.9301 - val_loss: 0.1591 - val_accuracy: 0.9356 - val_precision: 0.9929 - val_recall: 0.9188
# Epoch 15/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1507 - accuracy: 0.9431 - precision: 0.9867 - recall: 0.9366 - val_loss: 1.2348 - val_accuracy: 0.7144 - val_precision: 1.0000 - val_recall: 0.6123
# Epoch 16/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1666 - accuracy: 0.9316 - precision: 0.9830 - recall: 0.9240 - val_loss: 0.1259 - val_accuracy: 0.9433 - val_precision: 0.9916 - val_recall: 0.9307
# 39/39 [==============================] - 3s 73ms/step - loss: 0.4919 - accuracy: 0.8301 - precision: 0.8047 - recall: 0.9615
# Loss: 0.4918883442878723,
# Accuracy: 0.8301281929016113,
# Precision: 0.8047210574150085,
# Recall: 0.9615384340286255

# %%
plot(model1[0])

# %% [markdown]
# #### 모델2 : BATCH_SIZE = 32,epoches = 25,optimizer = 'adam',rugularizer = 0,class_weight = class_weight,augment = True

# %%
model2 = modify_params(BATCH_SIZE = 32)
# Out:
# Epoch 1/25
# 130/130 [==============================] - 40s 249ms/step - loss: 0.6037 - accuracy: 0.7085 - precision: 0.9001 - recall: 0.6798 - val_loss: 0.5884 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# Epoch 2/25
# 130/130 [==============================] - 32s 245ms/step - loss: 0.2931 - accuracy: 0.8912 - precision: 0.9747 - recall: 0.8781 - val_loss: 0.7391 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 3/25
# 130/130 [==============================] - 32s 243ms/step - loss: 0.2328 - accuracy: 0.9095 - precision: 0.9735 - recall: 0.9030 - val_loss: 0.8406 - val_accuracy: 0.7344 - val_precision: 0.7344 - val_recall: 1.0000
# Epoch 4/25
# 130/130 [==============================] - 31s 241ms/step - loss: 0.2099 - accuracy: 0.9224 - precision: 0.9755 - recall: 0.9187 - val_loss: 1.0040 - val_accuracy: 0.7354 - val_precision: 0.7354 - val_recall: 1.0000
# Epoch 5/25
# 130/130 [==============================] - 32s 245ms/step - loss: 0.2003 - accuracy: 0.9261 - precision: 0.9768 - recall: 0.9233 - val_loss: 0.6966 - val_accuracy: 0.7363 - val_precision: 0.7363 - val_recall: 1.0000
# 20/20 [==============================] - 3s 143ms/step - loss: 1.2387 - accuracy: 0.6250 - precision: 0.6250 - recall: 1.0000
# Loss: 1.238698124885559,
# Accuracy: 0.625,
# Precision: 0.625,
# Recall: 1.0

# %%
plot(model2[0])

# %% [markdown]
# #### 모델3 : BATCH_SIZE = 8,epoches = 25,optimizer = 'adam',rugularizer = 0,class_weight = class_weight,augment = True

# %%
model3 = modify_params(BATCH_SIZE = 8)
# Out:
# Epoch 1/25
# 523/523 [==============================] - 64s 74ms/step - loss: 0.5516 - accuracy: 0.7237 - precision: 0.9005 - recall: 0.7052 - val_loss: 0.5821 - val_accuracy: 0.7356 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 2/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.3786 - accuracy: 0.8355 - precision: 0.9488 - recall: 0.8222 - val_loss: 0.4435 - val_accuracy: 0.8010 - val_precision: 0.7866 - val_recall: 1.0000
# Epoch 3/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.3595 - accuracy: 0.8412 - precision: 0.9547 - recall: 0.8279 - val_loss: 2.9670 - val_accuracy: 0.3115 - val_precision: 1.0000 - val_recall: 0.0616
# Epoch 4/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.3414 - accuracy: 0.8431 - precision: 0.9496 - recall: 0.8333 - val_loss: 0.3489 - val_accuracy: 0.8337 - val_precision: 0.8202 - val_recall: 0.9908
# Epoch 5/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.3123 - accuracy: 0.8702 - precision: 0.9618 - recall: 0.8592 - val_loss: 0.2574 - val_accuracy: 0.8865 - val_precision: 0.9894 - val_recall: 0.8549
# Epoch 6/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.2624 - accuracy: 0.8985 - precision: 0.9765 - recall: 0.8843 - val_loss: 0.1395 - val_accuracy: 0.9519 - val_precision: 0.9811 - val_recall: 0.9529
# Epoch 7/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.2968 - accuracy: 0.8762 - precision: 0.9647 - recall: 0.8652 - val_loss: 0.2169 - val_accuracy: 0.9202 - val_precision: 0.9899 - val_recall: 0.9007
# Epoch 8/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.2805 - accuracy: 0.8817 - precision: 0.9672 - recall: 0.8713 - val_loss: 0.1939 - val_accuracy: 0.9087 - val_precision: 0.9653 - val_recall: 0.9085
# Epoch 9/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.3021 - accuracy: 0.8670 - precision: 0.9640 - recall: 0.8542 - val_loss: 0.3545 - val_accuracy: 0.8510 - val_precision: 0.9935 - val_recall: 0.8029
# Epoch 10/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.3007 - accuracy: 0.8751 - precision: 0.9676 - recall: 0.8605 - val_loss: 0.1606 - val_accuracy: 0.9404 - val_precision: 0.9377 - val_recall: 0.9843
# 78/78 [==============================] - 3s 39ms/step - loss: 0.9625 - accuracy: 0.6923 - precision: 0.6725 - recall: 0.9897
# Loss: 0.962533712387085,
# Accuracy: 0.692307710647583,
# Precision: 0.6724738478660583,
# Recall: 0.9897435903549194

# %%
plot(model3[0])

# %% [markdown]
# #### model4 Dropout없이 BN만 진행했을 경우

# %% [markdown]
# #### 모델4 : BATCH_SIZE = 8,epoches = 25,optimizer = 'adam',rugularizer = 0,class_weight = class_weight,augment = True

# %%
model4 = modify_params(BATCH_SIZE = 8)
# Out:
# Epoch 1/25
# 523/523 [==============================] - 46s 74ms/step - loss: 0.4987 - accuracy: 0.7554 - precision: 0.9262 - recall: 0.7267 - val_loss: 0.7317 - val_accuracy: 0.7365 - val_precision: 0.7365 - val_recall: 1.0000
# Epoch 2/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.2823 - accuracy: 0.8727 - precision: 0.9640 - recall: 0.8611 - val_loss: 3.8651 - val_accuracy: 0.2663 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/25
# 523/523 [==============================] - 37s 72ms/step - loss: 0.2671 - accuracy: 0.8894 - precision: 0.9733 - recall: 0.8767 - val_loss: 0.4107 - val_accuracy: 0.7913 - val_precision: 0.7792 - val_recall: 1.0000
# Epoch 4/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.2617 - accuracy: 0.8965 - precision: 0.9716 - recall: 0.8874 - val_loss: 0.4878 - val_accuracy: 0.7154 - val_precision: 1.0000 - val_recall: 0.6141
# Epoch 5/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.2352 - accuracy: 0.8925 - precision: 0.9771 - recall: 0.8765 - val_loss: 0.6370 - val_accuracy: 0.7731 - val_precision: 1.0000 - val_recall: 0.6911
# Epoch 6/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.2141 - accuracy: 0.9165 - precision: 0.9754 - recall: 0.9108 - val_loss: 1.4866 - val_accuracy: 0.4279 - val_precision: 1.0000 - val_recall: 0.2222
# Epoch 7/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.1953 - accuracy: 0.9183 - precision: 0.9823 - recall: 0.9074 - val_loss: 0.1536 - val_accuracy: 0.9394 - val_precision: 0.9631 - val_recall: 0.9542
# Epoch 8/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.1657 - accuracy: 0.9302 - precision: 0.9782 - recall: 0.9265 - val_loss: 0.6530 - val_accuracy: 0.7529 - val_precision: 1.0000 - val_recall: 0.6641
# Epoch 9/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.1931 - accuracy: 0.9269 - precision: 0.9778 - recall: 0.9218 - val_loss: 0.2146 - val_accuracy: 0.9317 - val_precision: 0.9929 - val_recall: 0.9137
# Epoch 10/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.1630 - accuracy: 0.9314 - precision: 0.9812 - recall: 0.9256 - val_loss: 0.1204 - val_accuracy: 0.9625 - val_precision: 0.9728 - val_recall: 0.9766
# Epoch 11/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.1548 - accuracy: 0.9397 - precision: 0.9787 - recall: 0.9389 - val_loss: 0.1524 - val_accuracy: 0.9587 - val_precision: 0.9878 - val_recall: 0.9556
# Epoch 12/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.2087 - accuracy: 0.9224 - precision: 0.9760 - recall: 0.9172 - val_loss: 0.2316 - val_accuracy: 0.9000 - val_precision: 0.9970 - val_recall: 0.8668
# Epoch 13/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.1573 - accuracy: 0.9461 - precision: 0.9807 - recall: 0.9462 - val_loss: 0.1728 - val_accuracy: 0.9346 - val_precision: 0.9820 - val_recall: 0.9282
# Epoch 14/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.1694 - accuracy: 0.9384 - precision: 0.9785 - recall: 0.9381 - val_loss: 0.1191 - val_accuracy: 0.9548 - val_precision: 0.9891 - val_recall: 0.9490
# Epoch 15/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.1316 - accuracy: 0.9487 - precision: 0.9842 - recall: 0.9466 - val_loss: 0.0793 - val_accuracy: 0.9779 - val_precision: 0.9881 - val_recall: 0.9817
# Epoch 16/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.1258 - accuracy: 0.9516 - precision: 0.9872 - recall: 0.9471 - val_loss: 0.3414 - val_accuracy: 0.9144 - val_precision: 0.9913 - val_recall: 0.8915
# Epoch 17/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.1357 - accuracy: 0.9454 - precision: 0.9833 - recall: 0.9413 - val_loss: 0.2863 - val_accuracy: 0.8587 - val_precision: 0.8386 - val_recall: 1.0000
# Epoch 18/25
# 523/523 [==============================] - 38s 73ms/step - loss: 0.1214 - accuracy: 0.9555 - precision: 0.9850 - recall: 0.9550 - val_loss: 0.0970 - val_accuracy: 0.9663 - val_precision: 0.9828 - val_recall: 0.9712
# Epoch 19/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.1138 - accuracy: 0.9613 - precision: 0.9903 - recall: 0.9575 - val_loss: 0.3069 - val_accuracy: 0.9308 - val_precision: 0.9819 - val_recall: 0.9228
# 78/78 [==============================] - 3s 39ms/step - loss: 0.5612 - accuracy: 0.8622 - precision: 0.8439 - recall: 0.9564
# Loss: 0.5612190365791321,
# Accuracy: 0.8621794581413269,
# Precision: 0.8438913822174072,
# Recall: 0.9564102292060852

# %%
plot(model4[0])

# %% [markdown]
# #### model5  BN없이 Dropout을 진행했을 경우

# %%
model5 = modify_params()
# Out:
# Epoch 1/25
# 261/261 [==============================] - 42s 133ms/step - loss: 0.3889 - accuracy: 0.8140 - precision: 0.9567 - recall: 0.7846 - val_loss: 0.6180 - val_accuracy: 0.7346 - val_precision: 0.7346 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.2194 - accuracy: 0.9090 - precision: 0.9729 - recall: 0.9029 - val_loss: 1.0698 - val_accuracy: 0.7375 - val_precision: 0.7375 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1957 - accuracy: 0.9216 - precision: 0.9781 - recall: 0.9149 - val_loss: 0.2431 - val_accuracy: 0.9087 - val_precision: 0.9912 - val_recall: 0.8837
# Epoch 4/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.1883 - accuracy: 0.9285 - precision: 0.9772 - recall: 0.9258 - val_loss: 0.1413 - val_accuracy: 0.9481 - val_precision: 0.9427 - val_recall: 0.9895
# Epoch 5/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1523 - accuracy: 0.9370 - precision: 0.9807 - recall: 0.9335 - val_loss: 0.2822 - val_accuracy: 0.8740 - val_precision: 0.9984 - val_recall: 0.8301
# Epoch 6/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1441 - accuracy: 0.9372 - precision: 0.9785 - recall: 0.9368 - val_loss: 0.1240 - val_accuracy: 0.9519 - val_precision: 0.9904 - val_recall: 0.9437
# Epoch 7/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1273 - accuracy: 0.9529 - precision: 0.9862 - recall: 0.9494 - val_loss: 0.0949 - val_accuracy: 0.9644 - val_precision: 0.9690 - val_recall: 0.9830
# Epoch 8/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.1570 - accuracy: 0.9432 - precision: 0.9867 - recall: 0.9368 - val_loss: 0.1007 - val_accuracy: 0.9625 - val_precision: 0.9866 - val_recall: 0.9620
# Epoch 9/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1231 - accuracy: 0.9510 - precision: 0.9862 - recall: 0.9471 - val_loss: 0.6905 - val_accuracy: 0.7048 - val_precision: 1.0000 - val_recall: 0.5992
# Epoch 10/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1188 - accuracy: 0.9541 - precision: 0.9874 - recall: 0.9506 - val_loss: 0.2330 - val_accuracy: 0.9144 - val_precision: 0.9913 - val_recall: 0.8915
# Epoch 11/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1328 - accuracy: 0.9480 - precision: 0.9849 - recall: 0.9451 - val_loss: 0.0955 - val_accuracy: 0.9625 - val_precision: 0.9879 - val_recall: 0.9607
# 39/39 [==============================] - 3s 73ms/step - loss: 1.0445 - accuracy: 0.7612 - precision: 0.7287 - recall: 0.9846
# Loss: 1.044458031654358,
# Accuracy: 0.7612179517745972,
# Precision: 0.7286527752876282,
# Recall: 0.9846153855323792

# %%
plot(model5[0])

# %% [markdown]
# #### model6 Dropout만 진행했을 경우

# %% [markdown]
# #### 모델6 : BATCH_SIZE = 8,epoches = 25,optimizer = 'adam',rugularizer = 0,class_weight = class_weight,augment = True

# %%
model6 = modify_params(BATCH_SIZE = 8)
# Out:
# Epoch 1/25
# 523/523 [==============================] - 44s 72ms/step - loss: 0.4804 - accuracy: 0.7554 - precision: 0.9005 - recall: 0.7558 - val_loss: 1.2296 - val_accuracy: 0.7365 - val_precision: 0.7365 - val_recall: 1.0000
# Epoch 2/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.3672 - accuracy: 0.8463 - precision: 0.9665 - recall: 0.8212 - val_loss: 1.3799 - val_accuracy: 0.7375 - val_precision: 0.7367 - val_recall: 1.0000
# Epoch 3/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.3331 - accuracy: 0.8710 - precision: 0.9733 - recall: 0.8493 - val_loss: 0.8283 - val_accuracy: 0.3894 - val_precision: 1.0000 - val_recall: 0.1710
# Epoch 4/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2510 - accuracy: 0.8782 - precision: 0.9736 - recall: 0.8605 - val_loss: 0.3667 - val_accuracy: 0.8019 - val_precision: 0.9964 - val_recall: 0.7330
# Epoch 5/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2337 - accuracy: 0.8992 - precision: 0.9797 - recall: 0.8844 - val_loss: 0.3001 - val_accuracy: 0.9240 - val_precision: 0.9329 - val_recall: 0.9659
# Epoch 6/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2665 - accuracy: 0.8825 - precision: 0.9752 - recall: 0.8648 - val_loss: 0.4546 - val_accuracy: 0.7635 - val_precision: 0.9981 - val_recall: 0.6797
# Epoch 7/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2461 - accuracy: 0.8892 - precision: 0.9788 - recall: 0.8701 - val_loss: 0.1872 - val_accuracy: 0.9452 - val_precision: 0.9682 - val_recall: 0.9567
# Epoch 8/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2334 - accuracy: 0.9076 - precision: 0.9813 - recall: 0.8926 - val_loss: 0.5206 - val_accuracy: 0.8510 - val_precision: 0.8330 - val_recall: 0.9974
# Epoch 9/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.1971 - accuracy: 0.9206 - precision: 0.9808 - recall: 0.9103 - val_loss: 0.1235 - val_accuracy: 0.9529 - val_precision: 0.9838 - val_recall: 0.9516
# Epoch 10/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.2102 - accuracy: 0.9205 - precision: 0.9811 - recall: 0.9108 - val_loss: 0.8335 - val_accuracy: 0.6356 - val_precision: 1.0000 - val_recall: 0.5046
# Epoch 11/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.1686 - accuracy: 0.9326 - precision: 0.9831 - recall: 0.9244 - val_loss: 0.2544 - val_accuracy: 0.8933 - val_precision: 0.9940 - val_recall: 0.8603
# Epoch 12/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.1707 - accuracy: 0.9328 - precision: 0.9801 - recall: 0.9288 - val_loss: 0.1180 - val_accuracy: 0.9644 - val_precision: 0.9765 - val_recall: 0.9752
# Epoch 13/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.1594 - accuracy: 0.9424 - precision: 0.9819 - recall: 0.9392 - val_loss: 0.1465 - val_accuracy: 0.9404 - val_precision: 0.9756 - val_recall: 0.9424
# Epoch 14/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.1872 - accuracy: 0.9235 - precision: 0.9815 - recall: 0.9145 - val_loss: 1.6304 - val_accuracy: 0.7442 - val_precision: 0.7420 - val_recall: 1.0000
# Epoch 15/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2111 - accuracy: 0.9179 - precision: 0.9828 - recall: 0.9069 - val_loss: 0.4400 - val_accuracy: 0.9067 - val_precision: 0.8901 - val_recall: 0.9961
# Epoch 16/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.1660 - accuracy: 0.9379 - precision: 0.9864 - recall: 0.9297 - val_loss: 0.2521 - val_accuracy: 0.8933 - val_precision: 0.9837 - val_recall: 0.8691
# 78/78 [==============================] - 3s 38ms/step - loss: 0.6204 - accuracy: 0.7997 - precision: 0.8018 - recall: 0.9026
# Loss: 0.6203778982162476,
# Accuracy: 0.7996794581413269,
# Precision: 0.801822304725647,
# Recall: 0.9025641083717346

# %% [markdown]
# #### model7 class_weight 없을 경우

# %% [markdown]
# ##### 모델7 : BATCH_SIZE = 8,epoches = 25,optimizer = 'adam',rugularizer = 0,class_weight = False,augment = True

# %%
model7 = modify_params(BATCH_SIZE = 8,class_weight = {0:1,1:1})
# Out:
# Epoch 1/25
# 523/523 [==============================] - 45s 73ms/step - loss: 0.4344 - accuracy: 0.8051 - precision: 0.8453 - recall: 0.9091 - val_loss: 1.9560 - val_accuracy: 0.7356 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 2/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2688 - accuracy: 0.8826 - precision: 0.9313 - recall: 0.9082 - val_loss: 0.3368 - val_accuracy: 0.7923 - val_precision: 0.7802 - val_recall: 0.9987
# Epoch 3/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2458 - accuracy: 0.9042 - precision: 0.9449 - recall: 0.9259 - val_loss: 2.8863 - val_accuracy: 0.2654 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2307 - accuracy: 0.9184 - precision: 0.9540 - recall: 0.9353 - val_loss: 1.1220 - val_accuracy: 0.2635 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/25
# 523/523 [==============================] - 37s 71ms/step - loss: 0.2155 - accuracy: 0.9222 - precision: 0.9482 - recall: 0.9461 - val_loss: 0.6625 - val_accuracy: 0.5894 - val_precision: 0.7666 - val_recall: 0.6353
# Epoch 6/25
# 523/523 [==============================] - 38s 72ms/step - loss: 0.1967 - accuracy: 0.9269 - precision: 0.9490 - recall: 0.9538 - val_loss: 0.7012 - val_accuracy: 0.5135 - val_precision: 1.0000 - val_recall: 0.3403
# 78/78 [==============================] - 3s 37ms/step - loss: 0.5480 - accuracy: 0.7035 - precision: 0.9767 - recall: 0.5385
# Loss: 0.5480074286460876,
# Accuracy: 0.7035256624221802,
# Precision: 0.9767441749572754,
# Recall: 0.5384615659713745

# %%
plot(model7[0])

# %% [markdown]
# ___

# %% [markdown]
# # 정리

# %% [markdown]
# - 폐 X-ray 사진을 통해 폐렴 이미지를 구분해보았다.

# %% [markdown]
# - 모델 다양한 parameters을 바꿔가며 영향을 확인해보았다.

# %% [markdown]
# 의료 이미지의 경우 데이터가 적기 때문에 기존 이미지를 상하,좌우 반전시켜 얻은 추가적인 데이터를 활용해서 모델을 개선했다.

# %% [markdown]
# 이처럼 단순 **data augmentation**만 진행했을 때 accuracy는 기존 80%에서 83%로 성능 개선을 확인할 수 있었다.

# %% [markdown]
# 85%까지 성능을 개선하기 위해서 Dropout + BN 레이어에서 둘 중 하나를 제거해본 결과 BN 레이어만 있을 때가 더 좋은 결과를 얻었다.

# %% [markdown]
# 결과적으로 accuracy를 85%까지 늘릴 수 있었다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 폐렴/정상 이미지가 불균형해 가중치를 조절해줬는데 이를 없애니 성능이 많이 나빠짐을 확인했다.

# %% [markdown]
# ___
